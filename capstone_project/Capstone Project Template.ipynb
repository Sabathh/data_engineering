# %% [markdown]
# # Project Title
# ### Data Engineering Capstone Project
#
# #### Project Summary
# --describe your project at a high level--
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
# Do all imports and installs here
from pyspark.sql import SparkSession
import pandas as pd

# %%
from extractor import Extractor
from transformer import Transformer

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# Explain what you plan to do in the project in more detail. What data do you use? What is your end solution look like? What tools did you use? etc>
#
# #### Describe and Gather Data
# Describe the data sets you're using. Where did it come from? What type of information is included?

# %%
filepaths = {
    'i94' : './data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat',
    'airports' : './data/airport-codes_csv.csv',
    'states' : './data/states.csv',
    'transport_modes' : './data/transport_mode.csv',
    'visa' : './data/visa.csv',
    'cities' : './data/us-cities-demographics.csv'
}

# %%
spark = SparkSession \
        .builder \
        .config("spark.jars.packages","saurfang:spark-sas7bdat:2.0.0-s_2.11")\
        .enableHiveSupport()\
        .getOrCreate()

# %%
extractor = Extractor(spark, filepaths)

# %%
df_airports = extractor.get_airport_data()
df_cities = extractor.get_cities_data()
df_states = extractor.get_states_data()
df_trasnp_modes = extractor.get_transp_mode_data()
df_visas = extractor.get_visa_data()

# %%
df_airports.toPandas()
# Out:
#          ident            type                                      name  \
# 0          00A        heliport                         Total Rf Heliport
# 1         00AA   small_airport                      Aero B Ranch Airport
# 2         00AK   small_airport                              Lowell Field
# 3         00AL   small_airport                              Epps Airpark
# 4         00AR          closed        Newport Hospital & Clinic Heliport
# 5         00AS   small_airport                            Fulton Airport
# 6         00AZ   small_airport                            Cordes Airport
# 7         00CA   small_airport                   Goldstone /Gts/ Airport
# 8         00CL   small_airport                       Williams Ag Airport
# 9         00CN        heliport           Kitchen Creek Helibase Heliport
# 10        00CO          closed                                Cass Field
# 11        00FA   small_airport                       Grass Patch Airport
# 12        00FD        heliport                        Ringhaver Heliport
# 13        00FL   small_airport                         River Oak Airport
# 14        00GA   small_airport                          Lt World Airport
# 15        00GE        heliport                          Caffrey Heliport
# 16        00HI        heliport                        Kaupulehu Heliport
# 17        00ID   small_airport                      Delta Shores Airport
# 18        00IG   small_airport                             Goltl Airport
# 19        00II        heliport        Bailey Generation Station Heliport
# 20        00IL   small_airport                            Hammer Airport
# 21        00IN        heliport           St Mary Medical Center Heliport
# 22        00IS   small_airport         Hayenga's Cant Find Farms Airport
# 23        00KS   small_airport                       Hayden Farm Airport
# 24        00KY   small_airport                     Robbins Roost Airport
# 25        00LA        heliport         Shell Chemical East Site Heliport
# 26        00LL        heliport                Ac & R Components Heliport
# 27        00LS   small_airport                           Lejeune Airport
# 28        00MD   small_airport                              Slater Field
# 29        00MI        heliport                     Dow Chemical Heliport
# ...        ...             ...                                       ...
# 55045     ZYAS  medium_airport                           Anshan Air Base
# 55046     ZYCC  medium_airport                           Longjia Airport
# 55047     ZYCH  medium_airport                          Changhai Airport
# 55048     ZYCY  medium_airport                          Chaoyang Airport
# 55049     ZYDU  medium_airport                  Wudalianchi Dedu Airport
# 55050     ZYFX   small_airport                             Fuxin Airport
# 55051     ZYFY  medium_airport                             Dongji Aiport
# 55052     ZYHB   large_airport                           Taiping Airport
# 55053     ZYHE  medium_airport                             Heihe Airport
# 55054     ZYJL   small_airport                             Jilin Airport
# 55055     ZYJM  medium_airport                           Jiamusi Airport
# 55056     ZYJS  medium_airport                      Jiansanjiang Airport
# 55057     ZYJX  medium_airport                    Jixi Xingkaihu Airport
# 55058     ZYJZ  medium_airport                           Jinzhou Airport
# 55059     ZYLD  medium_airport                             Lindu Airport
# 55060     ZYLS  medium_airport                      Yushu Batang Airport
# 55061     ZYMD  medium_airport  Mudanjiang Hailang International Airport
# 55062     ZYMH  medium_airport                           Gu-Lian Airport
# 55063     ZYQQ  medium_airport                  Qiqihar Sanjiazi Airport
# 55064     ZYSQ  medium_airport                 Songyuan Chaganhu Airport
# 55065     ZYTH   small_airport                              Tahe Airport
# 55066     ZYTL   large_airport                        Zhoushuizi Airport
# 55067     ZYTN  medium_airport                 Tonghua Sanyuanpu Airport
# 55068     ZYTX   large_airport                           Taoxian Airport
# 55069     ZYYJ  medium_airport               Yanji Chaoyangchuan Airport
# 55070     ZYYK  medium_airport                     Yingkou Lanqi Airport
# 55071     ZYYY  medium_airport                   Shenyang Dongta Airport
# 55072  ZZ-0001        heliport                           Sealand Helipad
# 55073  ZZ-0002   small_airport                 Glorioso Islands Airstrip
# 55074     ZZZZ   small_airport                   Satsuma IÅjima Airport
#
#       elevation_ft continent iso_country iso_region  \
# 0               11        NA          US      US-PA
# 1             3435        NA          US      US-KS
# 2              450        NA          US      US-AK
# 3              820        NA          US      US-AL
# 4              237        NA          US      US-AR
# 5             1100        NA          US      US-OK
# 6             3810        NA          US      US-AZ
# 7             3038        NA          US      US-CA
# 8               87        NA          US      US-CA
# 9             3350        NA          US      US-CA
# 10            4830        NA          US      US-CO
# 11              53        NA          US      US-FL
# 12              25        NA          US      US-FL
# 13              35        NA          US      US-FL
# 14             700        NA          US      US-GA
# 15             957        NA          US      US-GA
# 16              43        NA          US      US-HI
# 17            2064        NA          US      US-ID
# 18            3359        NA          US      US-KS
# 19             600        NA          US      US-IN
# 20             840        NA          US      US-IL
# 21             634        NA          US      US-IN
# 22             820        NA          US      US-IL
# 23            1100        NA          US      US-KS
# 24            1265        NA          US      US-KY
# 25              15        NA          US      US-LA
# 26             600        NA          US      US-IL
# 27              12        NA          US      US-LA
# 28              45        NA          US      US-MD
# 29             588        NA          US      US-MI
# ...            ...       ...         ...        ...
# 55045         None        AS          CN      CN-21
# 55046          706        AS          CN      CN-22
# 55047           80        AS          CN      CN-21
# 55048          568        AS          CN      CN-21
# 55049          984        AS          CN      CN-23
# 55050          548        AS          CN      CN-21
# 55051         None        AS          CN      CN-23
# 55052          457        AS          CN      CN-23
# 55053         8530        AS          CN      CN-23
# 55054         None        AS          CN      CN-22
# 55055          262        AS          CN      CN-23
# 55056         None        AS          CN      CN-23
# 55057          760        AS          CN      CN-23
# 55058         None        AS          CN      CN-21
# 55059          791        AS          CN      CN-23
# 55060        12816        AS          CN      CN-63
# 55061          883        AS          CN      CN-23
# 55062         1836        AS          CN      CN-23
# 55063          477        AS          CN      CN-23
# 55064          459        AS          CN      CN-22
# 55065         1240        AS          CN      CN-23
# 55066          107        AS          CN      CN-21
# 55067         1200        AS          CN      CN-22
# 55068          198        AS          CN      CN-21
# 55069          624        AS          CN      CN-22
# 55070            0        AS          CN      CN-21
# 55071         None        AS          CN      CN-21
# 55072           40        EU          GB     GB-ENG
# 55073           11        AF          TF     TF-U-A
# 55074          338        AS          JP      JP-46
#
#                                municipality gps_code iata_code local_code  \
# 0                                  Bensalem      00A      None        00A
# 1                                     Leoti     00AA      None       00AA
# 2                              Anchor Point     00AK      None       00AK
# 3                                   Harvest     00AL      None       00AL
# 4                                   Newport     None      None       None
# 5                                      Alex     00AS      None       00AS
# 6                                    Cordes     00AZ      None       00AZ
# 7                                   Barstow     00CA      None       00CA
# 8                                     Biggs     00CL      None       00CL
# 9                               Pine Valley     00CN      None       00CN
# 10                               Briggsdale     None      None       None
# 11                                 Bushnell     00FA      None       00FA
# 12                                Riverview     00FD      None       00FD
# 13                               Okeechobee     00FL      None       00FL
# 14                                 Lithonia     00GA      None       00GA
# 15                                    Hiram     00GE      None       00GE
# 16                              Kailua/Kona     00HI      None       00HI
# 17                               Clark Fork     00ID      None       00ID
# 18                                 McDonald     00IG      None       00IG
# 19                               Chesterton     00II      None       00II
# 20                                     Polo     00IL      None       00IL
# 21                                   Hobart     00IN      None       00IN
# 22                                    Kings     00IS      None       00IS
# 23                                  Gardner     00KS      None       00KS
# 24                                 Stanford     00KY      None       00KY
# 25                                 Gonzales     00LA      None       00LA
# 26                                  Chatham     00LL      None       00LL
# 27                                Esterwood     00LS      None       00LS
# 28                             Federalsburg     00MD      None       00MD
# 29                                Ludington     00MI      None       00MI
# ...                                     ...      ...       ...        ...
# 55045                                Anshan     ZYAS       AOG       None
# 55046                             Changchun     ZYCC       CGQ       None
# 55047                              Changhai     ZYCH       CNI       None
# 55048                              Chaoyang     ZYCY       CHG       None
# 55049                           Wudalianchi     ZYDU       DTU       None
# 55050                                 Fuxin     ZYFX      None       None
# 55051                                Fuyuan     ZYFY       FYJ       None
# 55052                                Harbin     ZYHB       HRB       None
# 55053                                 Heihe     ZYHE       HEK       None
# 55054                                 Jilin     ZYJL       JIL       None
# 55055                               Jiamusi     ZYJM       JMU       None
# 55056                          Jiansanjiang     ZYJS       JSJ       None
# 55057                                  Jixi     ZYJX       JXA       None
# 55058                               Jinzhou     ZYJZ       JNZ       None
# 55059                                Yichun     ZYLD       LDS       None
# 55060                                 Yushu     ZYLS       YUS       None
# 55061                            Mudanjiang     ZYMD       MDG       None
# 55062                                  Mohe     ZYMH       OHE       None
# 55063                               Qiqihar     ZYQQ       NDG       None
# 55064  Qian Gorlos Mongol Autonomous County     ZYSQ       YSQ       None
# 55065                                  Tahe     ZYTH      None       None
# 55066                                Dalian     ZYTL       DLC       None
# 55067                               Tonghua     ZYTN       TNH       None
# 55068                              Shenyang     ZYTX       SHE       None
# 55069                                 Yanji     ZYYJ       YNJ       None
# 55070                               Yingkou     ZYYK       YKH       None
# 55071                              Shenyang     ZYYY      None       None
# 55072                               Sealand     None      None       None
# 55073                      Grande Glorieuse     None      None       None
# 55074                          Mishima-Mura     RJX7      None       None
#
#                                    coordinates
# 0           -74.93360137939453, 40.07080078125
# 1                       -101.473911, 38.704022
# 2                  -151.695999146, 59.94919968
# 3        -86.77030181884766, 34.86479949951172
# 4                          -91.254898, 35.6087
# 5                      -97.8180194, 34.9428028
# 6      -112.16500091552734, 34.305599212646484
# 7           -116.888000488, 35.350498199499995
# 8                       -121.763427, 39.427188
# 9                     -116.4597417, 32.7273736
# 10                      -104.344002, 40.622202
# 11       -82.21900177001953, 28.64550018310547
# 12      -82.34539794921875, 28.846599578857422
# 13      -80.96920013427734, 27.230899810791016
# 14       -84.06829833984375, 33.76750183105469
# 15       -84.73390197753906, 33.88420104980469
# 16                      -155.980233, 19.832715
# 17     -116.21399688720703, 48.145301818847656
# 18                      -101.395994, 39.724028
# 19        -87.122802734375, 41.644500732421875
# 20        -89.5604019165039, 41.97840118408203
# 21        -87.2605972290039, 41.51139831542969
# 22        -89.1229019165039, 40.02560043334961
# 23       -94.93049621582031, 38.72779846191406
# 24      -84.61969757080078, 37.409400939941406
# 25                       -90.980833, 30.191944
# 26       -89.70559692382812, 39.66529846191406
# 27       -92.42939758300781, 30.13629913330078
# 28       -75.75379943847656, 38.75709915161133
# 29       -86.41670227050781, 43.94940185546875
# ...                                        ...
# 55045                    122.853996, 41.105301
# 55046             125.684997559, 43.9962005615
# 55047             122.666944444, 39.2666666667
# 55048                    120.434998, 41.538101
# 55049                          126.133, 48.445
# 55050                    121.718122, 42.069014
# 55051                    134.366447, 48.199494
# 55052                 126.25, 45.6234016418457
# 55053             127.308883667, 50.1716209371
# 55054                    126.396004, 44.002201
# 55055         130.464996338, 46.84339904789999
# 55056                        132.660278, 47.11
# 55057                          131.193, 45.293
# 55058    121.06199645996094, 41.10139846801758
# 55059                129.019125, 47.7520555556
# 55060        97.0363888889, 32.836388888900004
# 55061             129.569000244, 44.5241012573
# 55062               122.43, 52.912777777799995
# 55063   123.91799926757812, 47.239601135253906
# 55064                    124.550178, 44.938114
# 55065             124.720222222, 52.2244444444
# 55066     121.53900146484375, 38.9656982421875
# 55067             125.703333333, 42.2538888889
# 55068   123.48300170898438, 41.639801025390625
# 55069             129.451004028, 42.8828010559
# 55070                      122.3586, 40.542524
# 55071   123.49600219726562, 41.784400939941406
# 55072                        1.4825, 51.894444
# 55073  47.296388888900005, -11.584277777799999
# 55074                    130.270556, 30.784722
#
# [55075 rows x 12 columns]

# %%
df_cities.toPandas()
# Out:
#                   City           State Median Age Male Population  \
# 0        Silver Spring        Maryland       33.8           40601
# 1               Quincy   Massachusetts       41.0           44129
# 2               Hoover         Alabama       38.5           38040
# 3     Rancho Cucamonga      California       34.5           88127
# 4               Newark      New Jersey       34.6          138040
# 5               Peoria        Illinois       33.1           56229
# 6             Avondale         Arizona       29.1           38712
# 7          West Covina      California       39.8           51629
# 8             O'Fallon        Missouri       36.0           41762
# 9           High Point  North Carolina       35.5           51751
# 10              Folsom      California       40.9           41051
# 11              Folsom      California       40.9           41051
# 12        Philadelphia    Pennsylvania       34.1          741270
# 13             Wichita          Kansas       34.6          192354
# 14             Wichita          Kansas       34.6          192354
# 15          Fort Myers         Florida       37.3           36850
# 16          Pittsburgh    Pennsylvania       32.9          149690
# 17              Laredo           Texas       28.8          124305
# 18            Berkeley      California       32.5           60142
# 19         Santa Clara      California       35.2           63278
# 20               Allen    Pennsylvania       33.5           60626
# 21             Hampton        Virginia       35.5           66214
# 22         Bolingbrook        Illinois       33.7           36295
# 23           Frederick        Maryland       36.1           33146
# 24              Sparks          Nevada       36.1           47780
# 25      Rancho Cordova      California       33.8           34844
# 26         Westminster        Colorado       37.8           54866
# 27            Lakewood        Colorado       37.7           76013
# 28               Flint        Michigan       35.3           48984
# 29           New Haven     Connecticut       29.9           63765
# ...                ...             ...        ...             ...
# 2861          Scranton    Pennsylvania       38.5           37975
# 2862            Aurora        Colorado       34.2          177899
# 2863          Redlands      California       36.2           33993
# 2864          Alhambra      California       41.0           42184
# 2865          Alhambra      California       41.0           42184
# 2866        Rio Rancho      New Mexico       38.3           47251
# 2867           Wyoming        Michigan       32.8           35967
# 2868           Reading    Pennsylvania       29.4           43668
# 2869            Rialto      California       31.6           49902
# 2870       Tallahassee         Florida       26.2           89390
# 2871             Hemet      California       36.8           38622
# 2872            Aurora        Illinois       31.7          101964
# 2873            Carmel         Indiana       39.9           42928
# 2874          Glendale      California       42.1           98181
# 2875        Des Moines            Iowa       34.5          103726
# 2876   College Station           Texas       22.9           54125
# 2877            Peoria         Arizona       36.9           80139
# 2878         Charlotte  North Carolina       34.3          396646
# 2879         Lafayette         Indiana       33.5           34313
# 2880           Abilene           Texas       31.3           65212
# 2881          Gulfport     Mississippi       35.1           33108
# 2882             Davis      California       26.3           33493
# 2883       Los Angeles      California       35.0         1958998
# 2884      Mount Vernon        New York       38.5           31876
# 2885         Lynchburg        Virginia       28.7           38614
# 2886          Stockton      California       32.5          150976
# 2887        Southfield        Michigan       41.6           31369
# 2888      Indianapolis         Indiana       34.1          410615
# 2889        Somerville   Massachusetts       31.0           41028
# 2890     Coral Springs         Florida       37.2           63316
#
#      Female Population Total Population Number of Veterans Foreign-born  \
# 0                41862            82463               1562        30908
# 1                49500            93629               4147        32935
# 2                46799            84839               4819         8229
# 3                87105           175232               5821        33878
# 4               143873           281913               5829        86253
# 5                62432           118661               6634         7517
# 6                41971            80683               4815         8355
# 7                56860           108489               3800        37038
# 8                43270            85032               5783         3269
# 9                58077           109828               5204        16315
# 10               35317            76368               4187        13234
# 11               35317            76368               4187        13234
# 12              826172          1567442              61995       205339
# 13              197601           389955              23978        40270
# 14              197601           389955              23978        40270
# 15               37165            74015               4312        15365
# 16              154695           304385              17728        28187
# 17              131484           255789               4921        68427
# 18               60829           120971               3736        25000
# 19               62938           126216               4426        52281
# 20               59581           120207               5691        19652
# 21               70240           136454              19638         6204
# 22               35801            72096               2951        15212
# 23               36336            69482               3870        14211
# 24               48318            96098               7315        15690
# 25               36182            71026               4590        17020
# 26               58251           113117               6512        11361
# 27               76576           152589               9988        14169
# 28               49313            98297               3757         2138
# 29               66545           130310               2567        25871
# ...                ...              ...                ...          ...
# 2861             39137            77112               5059         8069
# 2862            180971           358870              25158        65816
# 2863             37035            71028               3445         8681
# 2864             43388            85572               1673        44441
# 2865             43388            85572               1673        44441
# 2866             46904            94155               8527         5200
# 2867             39310            75277               3447         8612
# 2868             44205            87873               2580        17043
# 2869             53235           103137               2036        32741
# 2870            100504           189894               9575        16720
# 2871             45251            83873               5613        13330
# 2872            101751           203715               4988        50980
# 2873             46101            89029               2723         9645
# 2874            102844           201025               4448       111510
# 2875            106591           210317              11780        23857
# 2876             53774           107899               2471        16145
# 2877             91103           171242              13019        14260
# 2878            430475           827121              36046       128897
# 2879             36857            71170               5045         5697
# 2880             60664           125876               9367         8129
# 2881             38764            71872               6646         3072
# 2882             34163            67656               2176        13997
# 2883           2012898          3971896              85417      1485425
# 2884             36745            68621               2064        23777
# 2885             41198            79812               4322         4364
# 2886            154674           305650              12822        79583
# 2887             41808            73177               4035         4011
# 2888            437808           848423              42186        72456
# 2889             39306            80334               2103        22292
# 2890             66186           129502               4724        38552
#
#      Average Household Size State Code                               Race  \
# 0                       2.6         MD                 Hispanic or Latino
# 1                      2.39         MA                              White
# 2                      2.58         AL                              Asian
# 3                      3.18         CA          Black or African-American
# 4                      2.73         NJ                              White
# 5                       2.4         IL  American Indian and Alaska Native
# 6                      3.18         AZ          Black or African-American
# 7                      3.56         CA                              Asian
# 8                      2.77         MO                 Hispanic or Latino
# 9                      2.65         NC                              Asian
# 10                     2.62         CA                 Hispanic or Latino
# 11                     2.62         CA  American Indian and Alaska Native
# 12                     2.61         PA                              Asian
# 13                     2.56         KS                 Hispanic or Latino
# 14                     2.56         KS  American Indian and Alaska Native
# 15                     2.45         FL                              White
# 16                     2.13         PA                              White
# 17                     3.66         TX  American Indian and Alaska Native
# 18                     2.35         CA                              Asian
# 19                     2.75         CA                              White
# 20                     2.67         PA          Black or African-American
# 21                     2.48         VA          Black or African-American
# 22                     3.42         IL  American Indian and Alaska Native
# 23                     2.48         MD                              White
# 24                     2.63         NV                 Hispanic or Latino
# 25                     2.86         CA                              Asian
# 26                     2.63         CO                 Hispanic or Latino
# 27                     2.29         CO                 Hispanic or Latino
# 28                     2.38         MI                              White
# 29                     2.48         CT  American Indian and Alaska Native
# ...                     ...        ...                                ...
# 2861                   2.39         PA                              Asian
# 2862                   2.82         CO                              Asian
# 2863                   2.82         CA                 Hispanic or Latino
# 2864                   2.89         CA                 Hispanic or Latino
# 2865                   2.89         CA          Black or African-American
# 2866                   2.86         NM          Black or African-American
# 2867                   2.65         MI  American Indian and Alaska Native
# 2868                   2.95         PA                              Asian
# 2869                   3.83         CA  American Indian and Alaska Native
# 2870                   2.38         FL                              Asian
# 2871                   2.97         CA                              Asian
# 2872                    3.3         IL          Black or African-American
# 2873                   2.71         IN                              White
# 2874                   2.69         CA                 Hispanic or Latino
# 2875                   2.41         IA                              White
# 2876                   2.52         TX                              White
# 2877                   2.97         AZ                              Asian
# 2878                   2.52         NC  American Indian and Alaska Native
# 2879                   2.19         IN                 Hispanic or Latino
# 2880                   2.64         TX          Black or African-American
# 2881                   2.54         MS                              White
# 2882                   2.69         CA  American Indian and Alaska Native
# 2883                   2.86         CA          Black or African-American
# 2884                   2.85         NY                 Hispanic or Latino
# 2885                   2.48         VA                              White
# 2886                   3.16         CA  American Indian and Alaska Native
# 2887                   2.27         MI  American Indian and Alaska Native
# 2888                   2.53         IN                              White
# 2889                   2.43         MA  American Indian and Alaska Native
# 2890                   3.17         FL                              White
#
#        Count
# 0      25924
# 1      58723
# 2       4759
# 3      24437
# 4      76402
# 5       1343
# 6      11592
# 7      32716
# 8       2583
# 9      11060
# 10      5822
# 11       998
# 12    122721
# 13     65162
# 14      8791
# 15     50169
# 16    208863
# 17      1253
# 18     27089
# 19     55847
# 20     22304
# 21     70303
# 22       323
# 23     49181
# 24     29159
# 25     12653
# 26     23355
# 27     33630
# 28     44786
# 29      2205
# ...      ...
# 2861    4722
# 2862   24673
# 2863   19698
# 2864   31386
# 2865    1905
# 2866    3970
# 2867    2444
# 2868     903
# 2869    1065
# 2870   10035
# 2871    3697
# 2872   23736
# 2873   77178
# 2874   30807
# 2875  168057
# 2876   84892
# 2877    6631
# 2878    8746
# 2879    9151
# 2880   14449
# 2881   42870
# 2882     779
# 2883  404868
# 2884    9446
# 2885   53727
# 2886   19834
# 2887     983
# 2888  553665
# 2889     374
# 2890   90896
#
# [2891 rows x 12 columns]

# %%
df_states.toPandas()
# Out:
#    state_code              state
# 0          AL            ALABAMA
# 1          AK             ALASKA
# 2          AZ            ARIZONA
# 3          AR           ARKANSAS
# 4          CA         CALIFORNIA
# 5          CO           COLORADO
# 6          CT        CONNECTICUT
# 7          DE           DELAWARE
# 8          DC  DIST. OF COLUMBIA
# 9          FL            FLORIDA
# 10         GA            GEORGIA
# 11         GU               GUAM
# 12         HI             HAWAII
# 13         ID              IDAHO
# 14         IL           ILLINOIS
# 15         IN            INDIANA
# 16         IA               IOWA
# 17         KS             KANSAS
# 18         KY           KENTUCKY
# 19         LA          LOUISIANA
# 20         ME              MAINE
# 21         MD           MARYLAND
# 22         MA      MASSACHUSETTS
# 23         MI           MICHIGAN
# 24         MN          MINNESOTA
# 25         MS        MISSISSIPPI
# 26         MO           MISSOURI
# 27         MT            MONTANA
# 28         NC        N. CAROLINA
# 29         ND          N. DAKOTA
# 30         NE           NEBRASKA
# 31         NV             NEVADA
# 32         NH      NEW HAMPSHIRE
# 33         NJ         NEW JERSEY
# 34         NM         NEW MEXICO
# 35         NY           NEW YORK
# 36         OH               OHIO
# 37         OK           OKLAHOMA
# 38         OR             OREGON
# 39         PA       PENNSYLVANIA
# 40         PR        PUERTO RICO
# 41         RI       RHODE ISLAND
# 42         SC        S. CAROLINA
# 43         SD          S. DAKOTA
# 44         TN          TENNESSEE
# 45         TX              TEXAS
# 46         UT               UTAH
# 47         VT            VERMONT
# 48         VI     VIRGIN ISLANDS
# 49         VA           VIRGINIA
# 50         WV        W. VIRGINIA
# 51         WA         WASHINGTON
# 52         WI          WISCONSON
# 53         WY           WYOMING
# 54         99    All Other Codes

# %%
df_trasnp_modes.toPandas()
# Out:
#   transport_mode_code transport_mode
# 0                   1            Air
# 1                   2            Sea
# 2                   3           Land
# 3                   9   Not reported

# %%
df_visas.toPandas()
# Out:
#   visa_code visa_type
# 0         1  Business
# 1         2  Pleasure
# 2         3   Student

# %%
df_i94 = extractor.get_i94_data()
df_i94.printSchema()
# Out:
# root
#  |-- cicid: double (nullable = true)
#  |-- i94yr: double (nullable = true)
#  |-- i94mon: double (nullable = true)
#  |-- i94cit: double (nullable = true)
#  |-- i94res: double (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: double (nullable = true)
#  |-- i94mode: double (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: double (nullable = true)
#  |-- i94bir: double (nullable = true)
#  |-- i94visa: double (nullable = true)
#  |-- count: double (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- visapost: string (nullable = true)
#  |-- occup: string (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- entdepu: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: double (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- insnum: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: double (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
df_cities.toPandas()['State Code'].unique()
# Out:
# array(['MD', 'MA', 'AL', 'CA', 'NJ', 'IL', 'AZ', 'MO', 'NC', 'PA', 'KS',
#        'FL', 'TX', 'VA', 'NV', 'CO', 'MI', 'CT', 'MN', 'UT', 'AR', 'TN',
#        'OK', 'WA', 'NY', 'GA', 'NE', 'KY', 'SC', 'LA', 'NM', 'IA', 'RI',
#        'PR', 'DC', 'WI', 'OR', 'NH', 'ND', 'DE', 'OH', 'ID', 'IN', 'AK',
#        'MS', 'HI', 'SD', 'ME', 'MT'], dtype=object)

# %%
#write to parquet
#df_spark.write.parquet("sas_data")
#df_spark=spark.read.parquet("sas_data")

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Identify data quality issues, like missing values, duplicate data, etc.
#
# #### Cleaning Steps
# Document steps necessary to clean the data

# %%
#states_list = [x.state_code for x in df_states.select('state_code').distinct().collect()]

# %%
#df_states.show()

# %%
df_airport_clean = Transformer.clean_airports(df_airports, df_states)
df_airport_clean.toPandas()
# Out:
#       ident   airport_type                                name elevation_ft  \
# 0       00A       heliport                   Total Rf Heliport           11
# 1      00AA  small_airport                Aero B Ranch Airport         3435
# 2      00AK  small_airport                        Lowell Field          450
# 3      00AL  small_airport                        Epps Airpark          820
# 4      00AS  small_airport                      Fulton Airport         1100
# 5      00AZ  small_airport                      Cordes Airport         3810
# 6      00CA  small_airport             Goldstone /Gts/ Airport         3038
# 7      00CL  small_airport                 Williams Ag Airport           87
# 8      00CN       heliport     Kitchen Creek Helibase Heliport         3350
# 9      00FA  small_airport                 Grass Patch Airport           53
# 10     00FD       heliport                  Ringhaver Heliport           25
# 11     00FL  small_airport                   River Oak Airport           35
# 12     00GA  small_airport                    Lt World Airport          700
# 13     00GE       heliport                    Caffrey Heliport          957
# 14     00HI       heliport                  Kaupulehu Heliport           43
# 15     00ID  small_airport                Delta Shores Airport         2064
# 16     00IG  small_airport                       Goltl Airport         3359
# 17     00II       heliport  Bailey Generation Station Heliport          600
# 18     00IL  small_airport                      Hammer Airport          840
# 19     00IN       heliport     St Mary Medical Center Heliport          634
# 20     00IS  small_airport   Hayenga's Cant Find Farms Airport          820
# 21     00KS  small_airport                 Hayden Farm Airport         1100
# 22     00KY  small_airport               Robbins Roost Airport         1265
# 23     00LA       heliport   Shell Chemical East Site Heliport           15
# 24     00LL       heliport          Ac & R Components Heliport          600
# 25     00LS  small_airport                     Lejeune Airport           12
# 26     00MD  small_airport                        Slater Field           45
# 27     00MI       heliport               Dow Chemical Heliport          588
# 28     00MN  small_airport       Battle Lake Municipal Airport         1365
# 29     00MO  small_airport       Cooper Flying Service Airport          970
# ...     ...            ...                                 ...          ...
# 21401   Y91  small_airport        Home Acres Sky Ranch Airport         1247
# 21402   Y96  small_airport         Leo E. Goetz County Airport          830
# 21403   Y98  small_airport                Grand Marais Airport          838
# 21404   Y99  small_airport                       Trulson Field         2105
# 21405   Z13  small_airport                    Akiachak Airport           23
# 21406   Z14  small_airport                     Tazlina Airport         2450
# 21407   Z17  small_airport                       Ophir Airport          575
# 21408   Z20  seaplane_base           Tuntutuliak Seaplane Base           15
# 21409   Z25  small_airport                      Tripod Airport          225
# 21410   Z33  seaplane_base             Aleknagik Seaplane Base            7
# 21411   Z40  small_airport                   Goose Bay Airport           78
# 21412   Z41  small_airport                     Lake Hood Strip           73
# 21413   Z43  seaplane_base         Tamgas Harbor Seaplane Base         None
# 21414   Z47  small_airport                      Engstrom Field          143
# 21415   Z48  small_airport                Bear Creek 3 Airport          740
# 21416   Z52  small_airport            Johnsons Landing Airport          130
# 21417   Z55  small_airport                 Lake Louise Airport         2450
# 21418   Z58  seaplane_base           Hangar Lake Seaplane Base           17
# 21419   Z59  seaplane_base                Bethel Seaplane Base           15
# 21420   Z71  seaplane_base             Cape Pole Seaplane Base            0
# 21421   Z78  seaplane_base           Chignik Bay Seaplane Base         None
# 21422   Z81  small_airport                 Salmon Lake Airport          490
# 21423   Z86  small_airport                  Clearwater Airport         2900
# 21424   Z87  seaplane_base            Blinn Lake Seaplane Base           50
# 21425   Z90  small_airport                    Stampede Airport         1850
# 21426   Z91  small_airport                 Birch Creek Airport          450
# 21427   Z92  small_airport              Harsens Island Airport          578
# 21428   Z93  small_airport             Copper Center 2 Airport         1150
# 21429   Z95  small_airport                     Cibecue Airport         5037
# 21430   ZNC  small_airport                        Nyac Airport          460
#
#       continent iso_country    municipality gps_code iata_code local_code  \
# 0            NA          US        Bensalem      00A      None        00A
# 1            NA          US           Leoti     00AA      None       00AA
# 2            NA          US    Anchor Point     00AK      None       00AK
# 3            NA          US         Harvest     00AL      None       00AL
# 4            NA          US            Alex     00AS      None       00AS
# 5            NA          US          Cordes     00AZ      None       00AZ
# 6            NA          US         Barstow     00CA      None       00CA
# 7            NA          US           Biggs     00CL      None       00CL
# 8            NA          US     Pine Valley     00CN      None       00CN
# 9            NA          US        Bushnell     00FA      None       00FA
# 10           NA          US       Riverview     00FD      None       00FD
# 11           NA          US      Okeechobee     00FL      None       00FL
# 12           NA          US        Lithonia     00GA      None       00GA
# 13           NA          US           Hiram     00GE      None       00GE
# 14           NA          US     Kailua/Kona     00HI      None       00HI
# 15           NA          US      Clark Fork     00ID      None       00ID
# 16           NA          US        McDonald     00IG      None       00IG
# 17           NA          US      Chesterton     00II      None       00II
# 18           NA          US            Polo     00IL      None       00IL
# 19           NA          US          Hobart     00IN      None       00IN
# 20           NA          US           Kings     00IS      None       00IS
# 21           NA          US         Gardner     00KS      None       00KS
# 22           NA          US        Stanford     00KY      None       00KY
# 23           NA          US        Gonzales     00LA      None       00LA
# 24           NA          US         Chatham     00LL      None       00LL
# 25           NA          US       Esterwood     00LS      None       00LS
# 26           NA          US    Federalsburg     00MD      None       00MD
# 27           NA          US       Ludington     00MI      None       00MI
# 28           NA          US     Battle Lake     00MN      None       00MN
# 29           NA          US            Alba     00MO      None       00MO
# ...         ...         ...             ...      ...       ...        ...
# 21401        NA          US       Lake City      Y91      None        Y91
# 21402        NA          US          Onaway      Y96      None        Y96
# 21403        NA          US    Grand Marais      Y98      None        Y98
# 21404        NA          US           Plaza      Y99      None        Y99
# 21405        NA          US        Akiachak      Z13       KKI        Z13
# 21406        NA          US         Tazlina      Z14      None        Z14
# 21407        NA          US           Ophir      Z17      None        Z17
# 21408        NA          US     Tuntutuliak      Z20      None        Z20
# 21409        NA          US       Aleknagik      Z25      None        Z25
# 21410        NA          US       Aleknagik      Z33      None        Z33
# 21411        NA          US       Goose Bay      Z40      None        Z40
# 21412        NA          US       Anchorage      Z41      None        Z41
# 21413        NA          US         Annette      Z43      None        Z43
# 21414        NA          US     Basin Creek     None      None        Z47
# 21415        NA          US      Bear Creek      Z48       BCC        Z48
# 21416        NA          US       Bear Lake      Z52      None        Z52
# 21417        NA          US     Lake Louise      Z55      None        Z55
# 21418        NA          US          Bethel     None      None        Z58
# 21419        NA          US          Bethel      Z59       JBT        Z59
# 21420        NA          US       Cape Pole      Z71       CZP        Z71
# 21421        NA          US         Chignik      Z78       KBW        Z78
# 21422        NA          US     Salmon Lake      Z81      None        Z81
# 21423        NA          US      Clearwater      Z86      None        Z86
# 21424        NA          US        Cold Bay      Z87      None        Z87
# 21425        NA          US       Kantishna      Z90      None        Z90
# 21426        NA          US     Birch Creek      Z91       KBC        Z91
# 21427        NA          US  Harsens Island      Z92      None        Z92
# 21428        NA          US   Copper Center      Z93       CZC        Z93
# 21429        NA          US         Cibecue      Z95      None        Z95
# 21430        NA          US            Nyac      ZNC       ZNC        ZNC
#
#                                    coordinates state
# 0           -74.93360137939453, 40.07080078125    PA
# 1                       -101.473911, 38.704022    KS
# 2                  -151.695999146, 59.94919968    AK
# 3        -86.77030181884766, 34.86479949951172    AL
# 4                      -97.8180194, 34.9428028    OK
# 5      -112.16500091552734, 34.305599212646484    AZ
# 6           -116.888000488, 35.350498199499995    CA
# 7                       -121.763427, 39.427188    CA
# 8                     -116.4597417, 32.7273736    CA
# 9        -82.21900177001953, 28.64550018310547    FL
# 10      -82.34539794921875, 28.846599578857422    FL
# 11      -80.96920013427734, 27.230899810791016    FL
# 12       -84.06829833984375, 33.76750183105469    GA
# 13       -84.73390197753906, 33.88420104980469    GA
# 14                      -155.980233, 19.832715    HI
# 15     -116.21399688720703, 48.145301818847656    ID
# 16                      -101.395994, 39.724028    KS
# 17        -87.122802734375, 41.644500732421875    IN
# 18        -89.5604019165039, 41.97840118408203    IL
# 19        -87.2605972290039, 41.51139831542969    IN
# 20        -89.1229019165039, 40.02560043334961    IL
# 21       -94.93049621582031, 38.72779846191406    KS
# 22      -84.61969757080078, 37.409400939941406    KY
# 23                       -90.980833, 30.191944    LA
# 24       -89.70559692382812, 39.66529846191406    IL
# 25       -92.42939758300781, 30.13629913330078    LA
# 26       -75.75379943847656, 38.75709915161133    MD
# 27       -86.41670227050781, 43.94940185546875    MI
# 28       -95.70030212402344, 46.29999923706055    MN
# 29           -94.412399291992, 37.202800750732    MO
# ...                                        ...   ...
# 21401     -85.17120361328125, 44.3203010559082    MI
# 21402     -84.2249984741211, 45.37080001831055    MI
# 21403    -85.91680145263672, 46.62080001831055    MI
# 21404   -101.9530029296875, 48.030601501464844    ND
# 21405        -161.42199707031, 60.904800415039    AK
# 21406   -146.46099853515625, 62.06480026245117    AK
# 21407  -156.52999877929688, 63.145999908447266    AK
# 21408            -162.666000366, 60.3414993286    AK
# 21409                   -158.557755, 59.263146    AK
# 21410   -158.62399291992188, 59.27399826049805    AK
# 21411   -149.8459930419922, 61.394500732421875    AK
# 21412    -149.96499633789062, 61.1869010925293    AK
# 21413    -131.5570068359375, 55.06800079345703    AK
# 21414                    -165.299205, 64.67909    AK
# 21415            -156.149454117, 63.5733160384    AK
# 21416   -160.26600646972656, 56.03670120239258    AK
# 21417     -146.57899475097656, 62.293701171875    AK
# 21418                   -161.727024, 60.803324    AK
# 21419       -161.742996216, 60.782001495399996    AK
# 21420             -133.79699707, 55.9663009644    AK
# 21421       -158.401000977, 56.295600891099994    AK
# 21422    -165.01300048828125, 64.9092025756836    AK
# 21423   -147.1790008544922, 63.026798248291016    AK
# 21424     -162.7530059814453, 55.2515983581543    AK
# 21425    -150.3300018310547, 63.74869918823242    AK
# 21426            -145.824005127, 66.2740020752    AK
# 21427   -82.57640075683594, 42.589698791503906    MI
# 21428            -145.294006348, 61.9412002563    AK
# 21429  -110.44400024414062, 34.003299713134766    AZ
# 21430            -159.994003296, 60.9807014465    AK
#
# [21431 rows x 12 columns]

# %%
df_airport_clean.select(df_airport_clean.airport_type).distinct().show(666)
# Out:
# +--------------+
# |  airport_type|
# +--------------+
# | large_airport|
# |   balloonport|
# | seaplane_base|
# |      heliport|
# |medium_airport|
# | small_airport|
# +--------------+

# %%
df_i94.select('i94bir').toPandas().describe()

# %%
for col in df_i94.columns:
    print("\n",col)
    print(df_i94.select(col).distinct().show(100))

# %%
# Performing cleaning tasks here
i94_table = df_i94.selectExpr(["i94yr as year",
                              "i94mon as month",
                              "i94cit as country_birth_id",
                              "i94res as country_residence_id",
                              "i94port as port_code",
                              "arrdate as arrival_date",
                              "i94mode as transport_mode",
                              "i94addr as state_code",
                              "depdate as departure_from_usa",
                              "i94bir as age",
                              "i94visa as visa_code",
                              "count",
                              "dtadfile",
                              "visapost",
                              "occup",
                              "entdepa",
                              "entdepd",
                              "entdepu",
                              "matflag",
                              "biryear as birth_year",
                              "dtaddto as allowed_to_stay_until",
                              "gender",
                              "insnum as ins_num",
                              "airline",
                              "admnum as admission_num",
                              "fltno as flight_num",
                              "visatype as visa_type"])

i94_table.printSchema()

# %%
i94_table.filter(i94_table.transport_mode==3.0).limit(10).toPandas()

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# Map out the conceptual data model and explain why you chose that model
#
# #### 3.2 Mapping Out Data Pipelines
# List the steps necessary to pipeline the data into the chosen data model

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %%
# Write code here

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %%
# Perform quality checks here

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# * Propose how often the data should be updated and why.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  * The database needed to be accessed by 100+ people.
